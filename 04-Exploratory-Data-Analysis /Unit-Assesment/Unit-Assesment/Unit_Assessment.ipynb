# %% [markdown]
# # Instructions

# %% [markdown]
# Read each question carefully and provide an appropriate answer in the following cells. Depending on the question, you may need to provide code or a text submission. **Be sure to label your answers with the question number for easy identification!**

# %% [markdown]
# **Question 1: Which of the following statements is the correct way to import a csv into a Pandas DataFrame? (2 points)**
#
# A.
#
# ```python
# import pandas as pd
# infile = pd.read_csv(file_name)
# ```
#
#
# B.
#
# ```python
# import pandas as pd
# infile = pd.readCSV(file_name)
# ```
#
#
# C.
#
# ```python
# import pandas as pd
# infile = read_file(file_name)
# ```
#
#
# D.
#
# ```python
# import pandas as pd
# df.read_file(file_name)
# ```

# %%
# Answer 1
A)

import pandas as pd
infile = pd.read_csv(file_name)

# %% [markdown]
# **Question 2: Create a code block that first imports the `student.json` file into a Pandas dataframe named `grades`, then creates a new dataframe named `passing` that contains only the students whose `Pass/Fail` status equals `PASS`. (5 points)**

# %%
# Answer 2
import pandas as pd
grades = pd.read_json('student.json')
grades
# Out:
#           Student Name  Midterm Exam  Midterm Paper  Final Exam  Final Paper  \
# 0   Jackqueline Durbin            85             84          90           56
# 1         Lina Petters            48             57          97           95
# 2      Hilaria Mcgehee            96            100          97           87
# 3          Leroy Dress            52             52          64           63
# 4        Raelene Bundy            89             57          90           85
# 5         Wayne Mellor            71             93          97           55
# 6        Sheena Bolten            97             90          70           83
# 7        Shyla Cupples            67             62          48           43
# 8          Ben Goforth           100             94          90           95
# 9         Alva Renshaw            88             61          45           47
# 10       Lucio Elswick            44             87          43           55
# 11     Mariana Hillwig            83             42          67           46
# 12          Elna Doane            59             43          43           52
# 13     Sang Pascarelli            54             47          92           57
# 14       Arianna Wagar            73             98          59           73
# 15        Antonio Kaur            75             72          87           53
# 16      Alethea Wyllie            90             97         100           97
# 17      Concetta Lucht            95             80          88           89
# 18      Jude Capetillo            66            100          93           82
# 19         Gladis Rank            46             74          92           87
# 20      Luciano Cuffie            94             92          86          100
# 21        Oren Okelley            55             52          76           48
# 22            Ha Ruano            41             44          95           55
# 23          Damon Sohn            53             97          74           53
#
#     Final Grade Pass/Fail Letter Grade
# 0            79      PASS            C
# 1            74      PASS            C
# 2            95      PASS            A
# 3            58      FAIL            F
# 4            80      PASS            B
# 5            79      PASS            C
# 6            85      PASS            B
# 7            55      FAIL            F
# 8            95      PASS            A
# 9            60      PASS            D
# 10           57      FAIL            F
# 11           60      PASS            D
# 12           49      FAIL            F
# 13           63      PASS            D
# 14           76      PASS            C
# 15           72      PASS            C
# 16           96      PASS            A
# 17           88      PASS            B
# 18           85      PASS            B
# 19           75      PASS            C
# 20           93      PASS            A
# 21           58      FAIL            F
# 22           59      FAIL            F
# 23           69      PASS            D

# %%
passing = grades[grades['Pass/Fail']=='PASS']
passing
# Out:
#           Student Name  Midterm Exam  Midterm Paper  Final Exam  Final Paper  \
# 0   Jackqueline Durbin            85             84          90           56
# 1         Lina Petters            48             57          97           95
# 2      Hilaria Mcgehee            96            100          97           87
# 4        Raelene Bundy            89             57          90           85
# 5         Wayne Mellor            71             93          97           55
# 6        Sheena Bolten            97             90          70           83
# 8          Ben Goforth           100             94          90           95
# 9         Alva Renshaw            88             61          45           47
# 11     Mariana Hillwig            83             42          67           46
# 13     Sang Pascarelli            54             47          92           57
# 14       Arianna Wagar            73             98          59           73
# 15        Antonio Kaur            75             72          87           53
# 16      Alethea Wyllie            90             97         100           97
# 17      Concetta Lucht            95             80          88           89
# 18      Jude Capetillo            66            100          93           82
# 19         Gladis Rank            46             74          92           87
# 20      Luciano Cuffie            94             92          86          100
# 23          Damon Sohn            53             97          74           53
#
#     Final Grade Pass/Fail Letter Grade
# 0            79      PASS            C
# 1            74      PASS            C
# 2            95      PASS            A
# 4            80      PASS            B
# 5            79      PASS            C
# 6            85      PASS            B
# 8            95      PASS            A
# 9            60      PASS            D
# 11           60      PASS            D
# 13           63      PASS            D
# 14           76      PASS            C
# 15           72      PASS            C
# 16           96      PASS            A
# 17           88      PASS            B
# 18           85      PASS            B
# 19           75      PASS            C
# 20           93      PASS            A
# 23           69      PASS            D

# %% [markdown]
# **Question 3: Create a code block that creates a Pandas dataframe with the following columns and values: (5 points)**
#
# * `Stock_Symbol`: AAPL, GOOG, TSLA, KO, MSFT
# * `Company_Name`: Apple, Google, Tesla, Coca-Cola, Microsoft
# * `52_Week_High`: 145.09, 1934.86, 900.40, 60.13, 242.64

# %%
# Answer 3
data = {'Stock_Symbol':['AAPL', 'GOOG', 'TSLA', 'KO', 'MSFT'], 'Company_Name':['Apple', 'Google', 'Tesla', 'Coca-Cola', 'Microsoft'],'52_Week_High':[145.09, 1934.86, 900.40, 60.13, 242.64]}
stocks_df = pd.DataFrame(data = data)
stocks_df
# Out:
#   Stock_Symbol Company_Name  52_Week_High
# 0         AAPL        Apple        145.09
# 1         GOOG       Google       1934.86
# 2         TSLA        Tesla        900.40
# 3           KO    Coca-Cola         60.13
# 4         MSFT    Microsoft        242.64

# %% [markdown]
# **Question 4: Which of the following `git` commands creates a new branch in your local repository? (2 points):**
#
# A. `git clone`
#
# B. `git pull <branch name>`
#
# C. `git checkout -b <branch name>`
#
# D. `git push -b <branch name>`

# %%
# Answer 4

#git checkout -b <branch name

# %% [markdown]
# **Question 5: Create a code block that performs the following operations: (10 points)**
#
#    1. Import the `bitcoin_cash_price.csv` file into a Pandas dataframe called `bitcoin`.
#
#    2. Import the `dash_price.csv` file into a Pandas dataframe called `dash`.
#
#    3. Merge the `bitcoin` and `dash` dataframes using the `Date` column as the identifier column. Name this new merged dataframe `crypto`.
#
#    4. Create a new `Delta_Volume` column in the `crypto` dataframe that calculates the largest **absolute** difference between the bitcoin `Volume` versus dash `Volume`.
#
#      * **Hint:** Use `abs()` to calculate absolute value.
#
#
#    5. Find the row in the `crypto` dataframe that contains the maximum `Delta_Volume` value. Print the row out.

# %%
# Answer 5
import pandas as pd
bitcoin = pd.read_csv('bitcoin_cash_price.csv')
dash = pd.read_csv('dash_price.csv')

# %%
crypto = pd.merge(bitcoin, dash, on="Date", suffixes=(' Bitcoin', ' Dash'))
crypto
# Out:
#          Date  Open Bitcoin  High Bitcoin  Low Bitcoin  Close Bitcoin  \
# 46    4.162070e+08      6,302,360,000     185.16     186.24    181.42
# 47    6.598880e+07                  -     179.20     186.23    177.26
# 48    1.075960e+06                  -     173.15     180.05    171.76
# 49    6.066950e+05                  -     185.45     187.95    172.47
# 50    7.378150e+05                  -     185.11     187.66    169.34
# 51    1.230160e+06                  -     194.00     196.91    181.57
# 52    5.332070e+05                  -     195.08     199.43    192.47
# 53    1.784640e+06                  -     195.49     200.88    189.33
# 54    5.249080e+05                  -     204.04     212.40    189.03
# 55    1.909520e+05                  -     191.11     216.62    187.29
# 56    8.501300e+04                  -     195.02     195.74    187.26
#
#     Close Dash  Volume Dash Market Cap Dash
# 0       313.84   38081600.0   2,257,850,000
# 1       298.86   43702600.0   2,150,800,000
# 2       284.36   72695500.0   1,784,040,000
# 3       236.24   35013800.0   2,275,100,000
# 4       301.29   28322500.0   2,452,930,000
# 5       325.97   27190400.0   2,404,680,000
# 6       318.40   25159900.0   2,431,230,000
# 7       320.11   27435400.0   2,439,780,000
# 8       323.14   23244600.0   2,527,540,000
# 9       333.21   63012500.0   2,591,570,000
# 10      343.91   24715700.0   2,612,980,000
# 11      347.17   35294300.0   2,474,300,000
# 12      327.23   53928800.0   2,388,710,000
# 13      316.13   44170200.0   2,689,920,000
# 14      356.39   34945200.0   2,670,270,000
# 15      350.17   54813400.0   2,962,400,000
# 16      393.35   55440700.0   2,844,110,000
# 17      378.32   34978600.0   2,773,030,000
# 18      368.34   44586300.0   2,704,790,000
# 19      359.55   50014900.0   2,685,760,000
# 20      356.78   57630700.0   2,725,220,000
# 21      362.89  121516000.0   3,009,530,000
# 22      399.85  267415000.0   2,369,010,000
# 23      315.89   53632700.0   2,388,160,000
# 24      315.37   58804500.0   2,200,130,000
# 25      292.57   47798300.0   2,180,790,000
# 26      291.50   74971200.0   2,103,900,000
# 27      279.58   58023900.0   2,204,480,000
# 28      294.20  107973000.0   2,162,080,000
# 29      288.70  220487000.0   1,685,040,000
# 30      224.28   50324200.0   1,753,350,000
# 31      233.62   98375500.0   1,736,000,000
# 32      232.02   63100100.0   1,527,710,000
# 33      203.52   37532600.0   1,496,920,000
# 34      199.44   29888400.0   1,485,500,000
# 35      198.17   36281800.0   1,539,490,000
# 36      205.49   30017500.0   1,543,820,000
# 37      205.79   28677400.0   1,502,990,000
# 38      200.96   30972000.0   1,493,200,000
# 39      199.21   31657100.0   1,524,040,000
# 40      203.84   35117200.0   1,470,120,000
# 41      197.19   32441600.0   1,413,570,000
# 42      189.13   25336000.0   1,447,880,000
# 43      193.83   41127900.0   1,397,060,000
# 44      186.97   28791800.0   1,395,520,000
# 45      186.99   25612400.0   1,367,150,000
# 46      182.93   19076200.0   1,381,630,000
# 47      184.75   34656300.0   1,336,810,000
# 48      178.51   29249300.0   1,291,390,000
# 49      172.82   25327200.0   1,382,710,000
# 50      185.25   40505200.0   1,379,860,000
# 51      185.61   30108800.0   1,445,720,000
# 52      194.09   26363200.0   1,453,370,000
# 53      194.37   38380000.0   1,456,070,000
# 54      195.52   84970400.0   1,519,340,000
# 27      279.58   58023900.0   2,204,480,000  1.065376e+09  1.065376e+09
# 28      294.20  107973000.0   2,162,080,000  1.386047e+09  1.386047e+09
# 29      288.70  220487000.0   1,685,040,000  2.975743e+09  2.975743e+09
# 30      224.28   50324200.0   1,753,350,000  3.037166e+09  3.037166e+09
# 31      233.62   98375500.0   1,736,000,000  6.462295e+08  6.462295e+08
# 32      232.02   63100100.0   1,527,710,000  4.333590e+07  4.333590e+07
# 33      203.52   37532600.0   1,496,920,000  9.639140e+07  9.639140e+07
# 34      199.44   29888400.0   1,485,500,000  1.450796e+08  1.450796e+08
# 35      198.17   36281800.0   1,539,490,000  8.444020e+07  8.444020e+07
# 36      205.49   30017500.0   1,543,820,000  9.598950e+07  9.598950e+07
# 37      205.79   28677400.0   1,502,990,000  2.052936e+08  2.052936e+08
# 38      200.96   30972000.0   1,493,200,000  1.056650e+08  1.056650e+08
# 39      199.21   31657100.0   1,524,040,000  1.333749e+08  1.333749e+08
# 40      203.84   35117200.0   1,470,120,000  2.397628e+08  2.397628e+08
# 41      197.19   32441600.0   1,413,570,000  3.141044e+08  3.141044e+08
# 42      189.13   25336000.0   1,447,880,000  8.227000e+07  8.227000e+07
# 43      193.83   41127900.0   1,397,060,000  1.029151e+08  1.029151e+08
# 44      186.97   28791800.0   1,395,520,000  1.562462e+08  1.562462e+08
# 45      186.99   25612400.0   1,367,150,000  1.359056e+08  1.359056e+08
# 46      182.93   19076200.0   1,381,630,000  3.971308e+08  3.971308e+08
# 47      184.75   34656300.0   1,336,810,000  3.133250e+07  3.133250e+07
# 48      178.51   29249300.0   1,291,390,000  2.817334e+07  2.817334e+07
# 49      172.82   25327200.0   1,382,710,000  2.472050e+07  2.472050e+07
# 50      185.25   40505200.0   1,379,860,000  3.976738e+07  3.976738e+07
# 51      185.61   30108800.0   1,445,720,000  2.887864e+07  2.887864e+07
# 52      194.09   26363200.0   1,453,370,000  2.582999e+07  2.582999e+07
# 53      194.37   38380000.0   1,456,070,000  3.659536e+07  3.659536e+07
# 54      195.52   84970400.0   1,519,340,000  8.444549e+07  8.444549e+07
# 55      204.02   90278800.0   1,422,690,000  9.008785e+07  9.008785e+07
# 56      191.03   31110400.0   1,451,390,000  3.102539e+07  3.102539e+07

# %%
max_delta = crypto['Delta_Volume'].max()
crypto[crypto['Delta_Volume'] == max_delta]
# Out:
#          Date  Open Bitcoin  High Bitcoin  Low Bitcoin  Close Bitcoin  \
# 30  18-Aug-17        458.67        764.07       458.67         690.24
#
#     Volume Bitcoin Market Cap Bitcoin  Open Dash  High Dash  Low Dash  \
# 30    3.087490e+09      7,565,590,000     233.84     240.41    219.42
#
#     Close Dash  Volume Dash Market Cap Dash   Delta_Volme  Delta_Volume
# 30      224.28   50324200.0   1,753,350,000  3.037166e+09  3.037166e+09

# %% [markdown]
# **Question 6: Which of the following statements adjusts the upper and lower limits on a Matplotlib visualization? (2 points)**
#
# A.
#
# ```python
# import matplotlib.pyplot as plt
# plt.hlines(0,25,0, alpha=0.25)
# ```
#
# B.
#
# ```python
# import matplotlib.pyplot as plt
# plt.xlim(0,25)
# plt.ylim(0,25)
# ```
#
# C.
# ```python
# import matplotlib.pyplot as plt
# plt.grid(0,25,0,25)
# ```
#
# D.
# ```python
# import matplotlib.pyplot as plt
# plt.upper(0,25)
# plt.lower(0,25)
# ```

# %%
# Answer 6
# B)

import matplotlib.pyplot as plt
plt.xlim(0,25)
plt.ylim(0,25)

# %% [markdown]
# **Question 7: Generate a bar plot that visualizes the following Netflix show IMDB ratings: (5 points)**
#
# `{"Series":["The Witcher","Disenchantment","Tiger King","Ozark","Stranger Things"],"User Ratings":[8.2,7.2,7.6,8.4,8.7]}`

# %%
# Answer 7
import matplotlib.pyplot as plt 

netflix_series = ["The Witcher","Disenchantment","Tiger King","Ozark","Stranger Things"]
ratings = [8.2,7.2,7.6,8.4,8.7]
netflix = pd.DataFrame(ratings,netflix_series)

plt.bar(netflix_series,ratings, width = 0.3)
plt.xlabel('Shows')
plt.ylabel('IMDB Rating')
# Out:
# Text(0, 0.5, 'IMDB Rating')

# %% [markdown]
# **Question 8: Which of the following statements corretly creates a Matplotlib visualization with four subplots? (2 points)**
#
# A. `plt.subplot()`
#
# B. `plt.subplot(1,2,3,4)`
#
# C. `plt.subplot(1,4)`
#
# D. `plt.subplot(2,2,1)`

# %%
# Answer 8

 # plt.subplot(2,2,1)

# %% [markdown]
# **Question 9: Which of the following Matplotlib methods would you use to add a label to your plot with an arrow pointing to the value? (2 points)**
#
# A. `plt.annotate()`
#
# B. `plt.label()`
#
# C. `plt.show()`
#
# D. `plt.arrow()`

# %%
# Answer 9

# plt.annotate()

# %% [markdown]
# **Question 10: Create a code block that performs the following operations: (15 points)**
#
# 1. Import the `earthquakes_database.csv` file into a Pandas dataframe named `earthquakes`
#
# 2. Retrieve the names of the unique data sources found in the `Source` column within your `earthquakes` dataframe.
#
#     * **Hint:** There should be 13 data sources.
#
#
# 3. Create a Matplotlib scatterplot for each data source that visualizes the `Magnitude` (y-axis) versus `Depth` (x-axis). Be sure to add axis labels to your axes and title each plot with the name of the data source.
#
#     * **Note:** You will need to filter the `earthquakes` dataframe for each category type.

# %%
# Answer 10
earthquakes = pd.read_csv('earthquakes_database.csv')
earthquakes
# Out:
#            Date      Time  Latitude  Longitude        Type   Depth  \
# 0        1/2/65  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1        1/4/65  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2        1/5/65  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3        1/8/65  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4        1/9/65  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...         ...       ...       ...        ...         ...     ...
# 23407  12/28/16   8:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/16   9:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/16  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/16  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/16  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude  10 ^ Magnitude  ...  \
# 0              NaN                     NaN        6.0    1.000000e+06  ...
# 1              NaN                     NaN        5.8    6.309573e+05  ...
# 2              NaN                     NaN        6.2    1.584893e+06  ...
# 3              NaN                     NaN        5.8    6.309573e+05  ...
# 4              NaN                     NaN        5.8    6.309573e+05  ...
# ...            ...                     ...        ...             ...  ...
# 23407          1.2                    40.0        5.6    3.981072e+05  ...
# 23408          2.0                    33.0        5.5    3.162278e+05  ...
# 23409          1.8                     NaN        5.9    7.943282e+05  ...
# 23410          1.8                     NaN        6.3    1.995262e+06  ...
# 23411          2.2                     NaN        5.5    3.162278e+05  ...
#
#       Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                            NaN            NaN                  NaN
# 1                            NaN            NaN                  NaN
# 2                            NaN            NaN                  NaN
# 3                            NaN            NaN                  NaN
# 4                            NaN            NaN                  NaN
# ...                          ...            ...                  ...
# 23407                       18.0          42.47                0.120
# 23408                       18.0          48.58                0.129
# 23409                        NaN          91.00                0.992
# 23410                        NaN          26.00                3.553
# 23411                      428.0          97.00                0.681
#
#        Horizontal Error  Root Mean Square            ID  Source  \
# 0                   NaN               NaN  ISCGEM860706  ISCGEM
# 1                   NaN               NaN  ISCGEM860737  ISCGEM
# 2                   NaN               NaN  ISCGEM860762  ISCGEM
# 3                   NaN               NaN  ISCGEM860856  ISCGEM
# 4                   NaN               NaN  ISCGEM860890  ISCGEM
# ...                 ...               ...           ...     ...
# 23407               NaN            0.1898    NN00570710      NN
# 23408               NaN            0.2187    NN00570744      NN
# 23409               4.8            1.5200    US10007NAF      US
# 23410               6.0            1.4300    US10007NL0      US
# 23411               4.5            0.9100    US10007NTD      US
#
#       Location Source Magnitude Source     Status
# 0              ISCGEM           ISCGEM  Automatic
# 1              ISCGEM           ISCGEM  Automatic
# 2              ISCGEM           ISCGEM  Automatic
# 3              ISCGEM           ISCGEM  Automatic
# 4              ISCGEM           ISCGEM  Automatic
# ...               ...              ...        ...
# 23407              NN               NN   Reviewed
# 23408              NN               NN   Reviewed
# 23409              US               US   Reviewed
# 23410              US               US   Reviewed
# 23411              US               US   Reviewed
#
# [23412 rows x 22 columns]

# %%
unique = list(earthquakes['Source'].unique())
unique
# Out:
# ['ISCGEM',
#  'ISCGEMSUP',
#  'OFFICIAL',
#  'CI',
#  'US',
#  'NC',
#  'GCMT',
#  'UW',
#  'ATLAS',
#  'NN',
#  'SE',
#  'AK',
#  'PR']

# %%
df = pd.DataFrame()
df['Source'] = earthquakes['Source']
df["Magnitude"] = earthquakes['Magnitude']
df["Depth"] = earthquakes['Depth']
df.head()
# Out:
#    Source  Magnitude  Depth
# 0  ISCGEM        6.0  131.6
# 1  ISCGEM        5.8   80.0
# 2  ISCGEM        6.2   20.0
# 3  ISCGEM        5.8   15.0
# 4  ISCGEM        5.8   15.0

# %%
for s in unique:
    source_id = earthquakes.loc[earthquakes.Source == s]
    plt.scatter(source_id.Depth, source_id.Magnitude,color = 'g')
    plt.title(x)
    plt.xlabel('Depth')
    plt.ylabel('Magnitude')
    plt.show()
